# %%
import numpy as np
import pandas as pd
import seaborn as sbn
import matplotlib.pyplot as plt
data = pd.read_excel("merc.xlsx")

# %%
data.describe()
# Out:
#                year          price        mileage           tax           mpg  \
# count  13119.000000   13119.000000   13119.000000  13119.000000  13119.000000
# mean    2017.296288   24698.596920   21949.559037    129.972178     55.155843
# std        2.224709   11842.675542   21176.512267     65.260286     15.220082
# min     1970.000000     650.000000       1.000000      0.000000      1.100000
# 25%     2016.000000   17450.000000    6097.500000    125.000000     45.600000
# 50%     2018.000000   22480.000000   15189.000000    145.000000     56.500000
# 75%     2019.000000   28980.000000   31779.500000    145.000000     64.200000
# max     2020.000000  159999.000000  259000.000000    580.000000    217.300000
#
#          engineSize
# count  13119.000000
# mean       2.071530
# std        0.572426
# min        0.000000
# 25%        1.800000
# 50%        2.000000
# 75%        2.100000
# max        6.200000

# %%
data.head()
# Out:
#    year  price transmission  mileage  tax   mpg  engineSize
# 0  2005   5200    Automatic    63000  325  32.1         1.8
# 1  2017  34948    Automatic    27000   20  61.4         2.1
# 2  2016  49948    Automatic     6200  555  28.0         5.5
# 3  2016  61948    Automatic    16000  325  30.4         4.0
# 4  2016  73948    Automatic     4000  325  30.1         4.0

# %%
data.isnull().sum() #eksik veri var mı
# Out:
# year            0
# price           0
# transmission    0
# mileage         0
# tax             0
# mpg             0
# engineSize      0
# dtype: int64

# %%
sbn.distplot(data["price"])

# %%
sbn.countplot(data["year"])

# %%
data.corr() #aralarındaki corolasyon ilişkisi
# Out:
#                 year     price   mileage       tax       mpg  engineSize
# year        1.000000  0.520712 -0.738027  0.012480 -0.094626   -0.142147
# price       0.520712  1.000000 -0.537214  0.268717 -0.438445    0.516126
# mileage    -0.738027 -0.537214  1.000000 -0.160223  0.202850    0.063652
# tax         0.012480  0.268717 -0.160223  1.000000 -0.513742    0.338341
# mpg        -0.094626 -0.438445  0.202850 -0.513742  1.000000   -0.339862
# engineSize -0.142147  0.516126  0.063652  0.338341 -0.339862    1.000000

# %%
data.corr()["price"].sort_values() #fiyatın diğer atributeler ile olan ilşkisi
# Out:
# mileage      -0.537214
# mpg          -0.438445
# tax           0.268717
# engineSize    0.516126
# year          0.520712
# price         1.000000
# Name: price, dtype: float64

# %%
sbn.scatterplot(data=data,x="mileage",y="price")

# %%
data.sort_values("price",ascending = False).head(20) #fiyatları en yuksek olan dan sıraldık. ascending = yükselen demek
# Out:
#        year   price transmission  mileage  tax   mpg  engineSize
# 6199   2020  159999    Semi-Auto     1350  145  21.4         4.0
# 10044  2020  154998    Automatic     3000  150  21.4         4.0
# 5      2011  149948    Automatic     3000  570  21.4         6.2
# 8737   2019  140319    Semi-Auto      785  150  22.1         4.0
# 6386   2018  139995    Semi-Auto    13046  145  21.4         4.0
# 8      2019  139948    Automatic    12000  145  21.4         4.0
# 9133   2019  139559    Semi-Auto     1000  145  22.1         4.0
# 8821   2020  138439    Semi-Auto     1000  145  22.1         4.0
# 5902   2018  135771    Semi-Auto    19000  145  21.4         4.0
# 7864   2018  135124    Semi-Auto    18234  150  21.4         4.0
# 8673   2019  134219    Semi-Auto     1000  145  24.8         4.0
# 6210   2019  129990    Automatic     1000  145  24.8         4.0
# 4759   2019  126000    Automatic      250  145  24.6         4.0
# ...

# %%
data.sort_values("price").head(20) #ascending true oldugu için küçkten büyüğe sıraldık.
# Out:
#        year  price transmission  mileage  tax   mpg  engineSize
# 11816  2003    650       Manual   109090  235  40.0         1.4
# 12008  2010   1350       Manual   116126  145  54.3         2.0
# 11765  2000   1490    Automatic    87000  265  27.2         3.2
# 11549  2002   1495    Automatic    13800  305  39.8         2.7
# 12594  2004   1495       Manual   119000  300  34.5         1.8
# 11174  2001   1695    Automatic   108800  325  31.7         3.2
# 12710  2006   1695    Automatic   153000  300  33.6         1.8
# 12766  2004   1780    Automatic   118000  265  41.5         2.2
# 12009  2007   1800    Automatic    84000  200  42.8         1.5
# 11764  1998   1990    Automatic    99300  265  32.1         2.3
# 11808  1998   1990    Automatic   113557  265  32.1         2.3
# 11383  2005   1995    Automatic   105000  260  43.5         2.1
# 11378  2004   1995    Semi-Auto   165000  330  20.0         3.7
# 11857  2002   2140    Automatic    52700  325  31.4         2.0
# ...

# %%
len(data)
# Out:
# 13119

# %%
len(data)*0.01 #yifatı en yuksek olan 131 aracı modelden cıkartalım.
# Out:
# 131.19

# %%
cleardata = data.sort_values("price", ascending = False).iloc[131:]

# %%
cleardata.describe()
# Out:
#                year         price        mileage           tax           mpg  \
# count  12988.000000  12988.000000   12988.000000  12988.000000  12988.000000
# mean    2017.281876  24074.926933   22132.741146    129.689714     55.437142
# std        2.228515   9866.224575   21196.776401     65.183076     15.025999
# min     1970.000000    650.000000       1.000000      0.000000      1.100000
# 25%     2016.000000  17357.500000    6322.000000    125.000000     45.600000
# 50%     2018.000000  22299.000000   15369.500000    145.000000     56.500000
# 75%     2019.000000  28706.000000   31982.250000    145.000000     64.200000
# max     2020.000000  65990.000000  259000.000000    580.000000    217.300000
#
#          engineSize
# count  12988.000000
# mean       2.050901
# std        0.532596
# min        0.000000
# 25%        1.675000
# 50%        2.000000
# 75%        2.100000
# max        6.200000

# %%
plt.figure(figsize=(7,5))
sbn.distplot(cleardata["price"])

# %%
data.groupby("year").mean()["price"] #BURADA 1970 YILININ SIKINTILI OLDGUNUN GÖRDUK
# Out:
# year
# 1970    24999.000000
# 1997     9995.000000
# 1998     8605.000000
# 1999     5995.000000
# 2000     5743.333333
# 2001     4957.900000
# 2002     5820.444444
# 2003     4878.000000
# 2004     4727.615385
# 2005     4426.111111
# 2006     4036.875000
# 2007     5136.045455
# 2008     6967.437500
# 2009     6166.764706
# 2010     8308.473684
# 2011    12624.894737
# 2012    10845.140351
# 2013    11939.842466
# 2014    14042.936864
# 2015    16731.780020
# 2016    19307.892948
# 2017    21514.307854
# 2018    25720.162918
# 2019    31290.020865
# 2020    35433.282337
# Name: price, dtype: float64

# %%
cleardata.groupby("year").mean()["price"] #BURADA 1970 YILININ SIKINTILI OLDGUNUN GÖRDUK
# Out:
# year
# 1970    24999.000000
# 1997     9995.000000
# 1998     8605.000000
# 1999     5995.000000
# 2000     5743.333333
# 2001     4957.900000
# 2002     5820.444444
# 2003     4878.000000
# 2004     4727.615385
# 2005     4426.111111
# 2006     4036.875000
# 2007     5136.045455
# 2008     6967.437500
# 2009     6166.764706
# 2010     8308.473684
# 2011     8913.459459
# 2012    10845.140351
# 2013    11939.842466
# 2014    14042.936864
# 2015    16647.822222
# 2016    19223.558943
# 2017    21356.280421
# 2018    24800.844506
# 2019    30289.524832
# 2020    34234.794872
# Name: price, dtype: float64

# %%
cleardata1 = cleardata[cleardata.year !=1970 ].groupby("year").mean()["price"] #kirli data olan 1970 modelleri çıkardık

# %%
cleardata1
# Out:
# year
# 1997     9995.000000
# 1998     8605.000000
# 1999     5995.000000
# 2000     5743.333333
# 2001     4957.900000
# 2002     5820.444444
# 2003     4878.000000
# 2004     4727.615385
# 2005     4426.111111
# 2006     4036.875000
# 2007     5136.045455
# 2008     6967.437500
# 2009     6166.764706
# 2010     8308.473684
# 2011     8913.459459
# 2012    10845.140351
# 2013    11939.842466
# 2014    14042.936864
# 2015    16647.822222
# 2016    19223.558943
# 2017    21356.280421
# 2018    24800.844506
# 2019    30289.524832
# 2020    34234.794872
# Name: price, dtype: float64

# %%
cleardata1.describe()
# Out:
# count       24.000000
# mean     11585.758565
# std       8566.887784
# min       4036.875000
# 25%       5591.511364
# 50%       8456.736842
# 75%      14694.158203
# max      34234.794872
# Name: price, dtype: float64

# %%
data = cleardata

# %%
data.describe()
# Out:
#                year         price        mileage           tax           mpg  \
# count  12988.000000  12988.000000   12988.000000  12988.000000  12988.000000
# mean    2017.281876  24074.926933   22132.741146    129.689714     55.437142
# std        2.228515   9866.224575   21196.776401     65.183076     15.025999
# min     1970.000000    650.000000       1.000000      0.000000      1.100000
# 25%     2016.000000  17357.500000    6322.000000    125.000000     45.600000
# 50%     2018.000000  22299.000000   15369.500000    145.000000     56.500000
# 75%     2019.000000  28706.000000   31982.250000    145.000000     64.200000
# max     2020.000000  65990.000000  259000.000000    580.000000    217.300000
#
#          engineSize
# count  12988.000000
# mean       2.050901
# std        0.532596
# min        0.000000
# 25%        1.675000
# 50%        2.000000
# 75%        2.100000
# max        6.200000

# %%
data = data[data.year !=1970]

# %%
data.describe() #ŞİMDİ DATAMIZ TERTEMİZ OLDU. trasnmissin kolonundanda kurtulalım
# Out:
#                year         price        mileage           tax           mpg  \
# count  12987.000000  12987.000000   12987.000000  12987.000000  12987.000000
# mean    2017.285516  24074.855779   22133.367367    129.676215     55.438392
# std        2.189633   9866.601115   21197.472376     65.167429     15.025902
# min     1997.000000    650.000000       1.000000      0.000000      1.100000
# 25%     2016.000000  17355.000000    6320.000000    125.000000     45.600000
# 50%     2018.000000  22299.000000   15371.000000    145.000000     56.500000
# 75%     2019.000000  28706.000000   31986.500000    145.000000     64.200000
# max     2020.000000  65990.000000  259000.000000    580.000000    217.300000
#
#          engineSize
# count  12987.000000
# mean       2.051059
# std        0.532313
# min        0.000000
# 25%        1.700000
# 50%        2.000000
# 75%        2.100000
# max        6.200000

# %%
data.groupby("year").mean()["price"]
# Out:
# year
# 1997     9995.000000
# 1998     8605.000000
# 1999     5995.000000
# 2000     5743.333333
# 2001     4957.900000
# 2002     5820.444444
# 2003     4878.000000
# 2004     4727.615385
# 2005     4426.111111
# 2006     4036.875000
# 2007     5136.045455
# 2008     6967.437500
# 2009     6166.764706
# 2010     8308.473684
# 2011     8913.459459
# 2012    10845.140351
# 2013    11939.842466
# 2014    14042.936864
# 2015    16647.822222
# 2016    19223.558943
# 2017    21356.280421
# 2018    24800.844506
# 2019    30289.524832
# 2020    34234.794872
# Name: price, dtype: float64

# %%
data.head()
# Out:
#       year  price transmission  mileage  tax   mpg  engineSize
# 6177  2019  65990    Semi-Auto     5076  150  30.4         3.0
# 5779  2020  65990    Semi-Auto      999  145  28.0         4.0
# 3191  2020  65980    Semi-Auto     3999  145  28.0         4.0
# 4727  2019  65000    Semi-Auto     3398  145  27.2         4.0
# 8814  2019  64999    Semi-Auto      119  145  40.9         3.0

# %%
data = data.drop("transmission",axis = 1)

# %%
data.head() #şimdi hazır.
# Out:
#       year  price  mileage  tax   mpg  engineSize
# 6177  2019  65990     5076  150  30.4         3.0
# 5779  2020  65990      999  145  28.0         4.0
# 3191  2020  65980     3999  145  28.0         4.0
# 4727  2019  65000     3398  145  27.2         4.0
# 8814  2019  64999      119  145  40.9         3.0

# %%
y = data["price"].values
x = data.drop("price",axis =1).values

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.3,random_state= 10)

# %%
len(x_train)
# Out:
# 9090

# %%
len(y_test)
# Out:
# 3897

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
scaler = MinMaxScaler()

# %%
x_train = scaler.fit_transform(x_train)
x_test = scaler.transform(x_test)

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

# %%
x_train.shape
# Out:
# (9090, 5)

# %%
model = Sequential()
model.add(Dense(12,activation = "relu"))
model.add(Dense(12,activation = "relu"))
model.add(Dense(12,activation = "relu"))
model.add(Dense(12,activation = "relu"))

model.add(Dense(1))

model.compile(optimizer = "adam",loss = "mse")
# Out:
# WARNING:tensorflow:From C:\Users\metea\anaconda3\lib\site-packages\tensorflow\python\ops\init_ops.py:1251: calling VarianceScaling.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor

# %%
model.fit(x = x_train,y = y_train,validation_data=(x_test,y_test),batch_size = 250, epochs = 300)
# Out:
# Train on 9090 samples, validate on 3897 samples
# Epoch 1/300
# 9090/9090 [==============================] - 1s 70us/sample - loss: 672138124.8845 - val_loss: 688088750.4111
# Epoch 2/300
# 9090/9090 [==============================] - 0s 5us/sample - loss: 672091491.8372 - val_loss: 688002110.9325
# Epoch 3/300
# 9090/9090 [==============================] - 0s 5us/sample - loss: 671935720.4136 - val_loss: 687737728.5748
# Epoch 4/300
# 9090/9090 [==============================] - 0s 5us/sample - loss: 671498264.9241 - val_loss: 687025665.2974
# Epoch 5/300
# 9090/9090 [==============================] - 0s 5us/sample - loss: 670341169.4961 - val_loss: 685187940.0647
# Epoch 6/300
# 9090/9090 [==============================] - 0s 5us/sample - loss: 667538452.4180 - val_loss: 680941430.5897
# Epoch 7/300
# 9090/9090 [==============================] - 0s 5us/sample - loss: 661417841.6370 - val_loss: 672192929.3056
# Epoch 8/300
# ...

# %%
kayıpveri = pd.DataFrame(model.history.history)
kayıpveri.head()
# Out:
#            loss      val_loss
# 0  6.721381e+08  6.880888e+08
# 1  6.720915e+08  6.880021e+08
# 2  6.719357e+08  6.877377e+08
# 3  6.714983e+08  6.870257e+08
# 4  6.703412e+08  6.851879e+08

# %%
kayıpveri.plot()

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error

# %%
tahmin = model.predict(x_test)

# %%
tahmin
# Out:
# array([[22697.006 ],
#        [23153.43  ],
#        [24571.955 ],
#        ...,
#        [26124.688 ],
#        [11812.2705],
#        [24533.305 ]], dtype=float32)

# %%
mean_absolute_error(y_test,tahmin) #3250 paundluk fark
# Out:
# 3223.4359246758827

# %%
plt.scatter(y_test,tahmin)
plt.plot(y_test,y_test,"g-*")

# %%
 data.iloc[2]
# Out:
# year           2020.0
# price         65980.0
# mileage        3999.0
# tax             145.0
# mpg              28.0
# engineSize        4.0
# Name: 3191, dtype: float64

# %%
yeniarac = data.drop("price",axis=1).iloc[2]

# %%
yeniarac
# Out:
# year          2020.0
# mileage       3999.0
# tax            145.0
# mpg             28.0
# engineSize       4.0
# Name: 3191, dtype: float64

# %%
yeniarac = scaler.transform(yeniarac.values.reshape(-1,5))
model.predict(yeniarac)
# Out:
# array([[62522.363]], dtype=float32)
