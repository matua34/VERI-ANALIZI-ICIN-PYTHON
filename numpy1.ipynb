# %%
import numpy as np

# %%
maas = np.random.normal(1500,350,250)

# %%
maas.max()
# Out:
# 2631.4718794386445

# %%
maas.min()
# Out:
# 520.6809084683633

# %%
maas.mean()
# Out:
# 1492.1742225388275

# %%
maas.std()
# Out:
# 349.49296105113945

# %%
maas.argmax()
# Out:
# 197

# %%
maas.max()
# Out:
# 2631.4718794386445

# %%
maas.argmin()
# Out:
# 244

# %%
maas.min()
# Out:
# 520.6809084683633

# %%
len(maas)
# Out:
# 250

# %%
yenimaas = maas.reshape(25,10)

# %%
 maas
# Out:
# array([2059.21204486, 1346.50575048, 1280.69329237, 1706.31399001,
#        1744.08662735, 2149.30810499,  775.27972926, 1051.7471222 ,
#        1532.84656418, 1721.89385339,  909.35243023, 1190.0913999 ,
#        1893.40784919, 1178.71839588, 1780.34753771, 1370.73842899,
#        1428.27735712, 1182.86249756, 1602.35188669, 1501.39215819,
#        1354.83818338, 1600.67178131, 1654.12251372,  828.50040144,
#        1712.10579686, 1062.74413656, 1773.37308847, 1699.8175599 ,
#        1424.77587048, 1409.65831138, 1178.04795295, 1118.97101386,
#        1402.88243623, 1349.69069237, 1458.71885793, 1305.06027413,
#        1161.62258858, 1701.52751269, 1514.48663938,  719.61208575,
#        1105.00289736, 1279.39937032,  906.63519645, 1515.81713405,
#        1617.40472246, 1770.72490823, 1650.60103185, 1617.25236306,
#         714.09322337, 1601.58331623, 1514.72552189, 1715.68098751,
#        1181.26185025, 1333.39276107, 1134.46868842, 1190.55202336,
# ...

# %%
maas.shape
# Out:
# (250,)

# %%
yenimaas.shape
# Out:
# (25, 10)
