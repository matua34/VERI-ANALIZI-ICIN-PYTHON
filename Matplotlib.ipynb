# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
# %matplotlib inline

# %%
yas = [10,20,30,30,40,50,60,60,70,75]

# %%
kilo =[22,33,80,45,60,67,78,65,55,59]

# %%
npyas = np.array(yas)
npkilo = np.array(kilo)

# %%
plt.plot(yas,kilo,"r")

# %%
plt.plot(npyas,npkilo,"g")
